# %%
import pynini as pn
from fst_utils import show_graph, get_paths
from malti2arabi import *

# %%
show_graph((pn.accep('abbc') @ pn.cdrewrite(pn.cross('bb','b~'), '', '', pn.union('a','b','c','g','~').closure()).optimize()))

# %%
x = translit('eyoo')
x
# Out:
# <vector Fst at 0x106e4e4b0>

# %%
translit('għgħ')
# Out:
# <vector Fst at 0x106e59bb0>
